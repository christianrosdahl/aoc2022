# %% [markdown]
# # Advent of Code 2022 - Day 7

# %% [markdown]
# ## Part 1

# %%
# Load data
file = open('input7.txt','r')
lines = file.readlines()
for i in range(len(lines)):
    lines[i] = lines[i].replace('\n', '')

# %%
# Create a list with the file system
file_system = []
level = 0
for line in lines:
    if '$ cd' in line and not '..' in line:
        _, _, dir_name = line.split()
        file_system.append([level, 'dir', dir_name])
        level += 1
    elif '$ cd ..' in line:
        level -= 1
    if not '$' in line and not 'dir ' in line:
        file_size, _ = line.split()
        file_system.append([level, 'file', int(file_size)])

# %%
def sum_files(file_system, start_index):
    # Sum files in file system contained in folder at start_index
    file_sum = 0
    start_level = file_system[start_index][0]
    for i in range(start_index + 1, len(file_system)):
        level, entry_type, value = file_system[i]
        if level <= start_level:
            break
        elif entry_type == 'file':
            file_sum += value
    return file_sum

# %%
# Compute directory sizes
dir_sizes = []
for i, line in enumerate(file_system):
    level, entry_type, value = line
    if entry_type == 'dir':
        dir_sizes.append(sum_files(file_system, i))

# %%
print('Directory sizes: ' + str(dir_sizes))
# Out:
# Directory sizes: [42805968, 10449487, 2919892, 2877389, 1927095, 252091, 374873, 470307, 242263, 228044, 30777, 736944, 155253, 22423, 6096648, 4008321, 2490397, 2177388, 795801, 733934, 51204, 64928, 61867, 331904, 846114, 583150, 11155, 192414, 313009, 550260, 247651, 1693637, 5264, 1429016, 478350, 271143, 64128, 187526, 1069296, 250912, 409913, 9998, 9998, 109025, 17428128, 500982, 500982, 500982, 252517, 5973492, 8600, 2623574, 1601353, 368529, 488529, 191709, 1022221, 1022221, 274776, 274776, 221327, 1735755, 161179, 365329, 176043, 114477, 114477, 74809, 557891, 475203, 986590, 368096, 275370, 5680367, 837222, 256105, 3908141, 433473, 293104, 178932, 2658141, 275481, 125627, 236951, 853242, 199196, 658741, 282867, 40866, 3127580, 2290224, 72812, 1196426, 292349, 130971, 274549, 424417, 173437, 641688, 289195, 289195, 550900, 1662116, 1002118, 655150, 254691, 151003, 103688, 113113, 134280, 134280, 134280, 134280, 11686814, 1540498, 328642, 359720, 2688184, 172788, 2465255, 108342, 774194, 325278, 18316, 18316, 110236, 448916, 1582719, 39153, 60625, 36016, 742497, 528016, 157880, 429451, 4254868, 2674857, 232575, 285116, 1284585, 325305, 104275, 400818, 111715, 788698, 247668, 541030, 1922310, 989965, 700074, 272856, 262298, 164920, 289891, 190002, 39093, 275854, 222492, 19102, 19102, 19102, 181610, 332119, 332119, 95079, 309278, 293736, 26404, 812195, 189696, 189696, 143510, 276725, 202264]

# %%
print('File system: ')
print('(level, type, name/size)')
for i in file_system:
    print(i)
# Out:
# File system:
# (level, type, name/size)
# [0, 'dir', '/']
# [1, 'file', 55644]
# [1, 'dir', 'cmwrq']
# [2, 'file', 16144]
# [2, 'file', 50956]
# [2, 'dir', 'dtbzzl']
# [3, 'file', 42503]
# [3, 'dir', 'wwpnn']
# [4, 'file', 58541]
# [4, 'file', 101609]
# [4, 'dir', 'lwqgsbg']
# [5, 'file', 207528]
# [5, 'file', 38543]
# [5, 'file', 106337]
# [5, 'file', 302201]
# [5, 'file', 175215]
# [5, 'dir', 'dtbzzl']
# [6, 'file', 252091]
# [5, 'dir', 'pjts']
# [6, 'file', 155681]
# [6, 'file', 219192]
# [5, 'dir', 'sbvljdh']
# [6, 'dir', 'rdrqc']
# [7, 'file', 242263]
# [6, 'dir', 'rtfpcswj']
# [7, 'file', 228044]
# [4, 'dir', 'nztw']
# [5, 'file', 30777]
# [4, 'dir', 'rdtjztmt']
# [5, 'file', 276602]
# [5, 'file', 305089]
# [5, 'dir', 'rzbb']
# [6, 'file', 155253]
# [4, 'dir', 'ssdlqcrw']
# [5, 'file', 22423]
# [2, 'dir', 'pjnghbm']
# [3, 'file', 189296]
# [3, 'file', 205394]
# [3, 'dir', 'dtbzzl']
# [4, 'file', 239152]
# [4, 'file', 39308]
# [4, 'file', 211316]
# [4, 'file', 230237]
# [4, 'dir', 'hlw']
# [5, 'dir', 'lfqqrp']
# [6, 'dir', 'mbmfpz']
# [7, 'dir', 'fsrbwl']
# [8, 'file', 154657]
# [8, 'file', 228929]
# [8, 'file', 234216]
# [8, 'dir', 'ltsj']
# [9, 'file', 51204]
# [8, 'dir', 'ssdlqcrw']
# [9, 'file', 64928]
# [7, 'dir', 'lsmpw']
# [8, 'file', 61867]
# [6, 'dir', 'mdhfdlw']
# [7, 'file', 92462]
# [7, 'file', 239442]
# [6, 'dir', 'pjts']
# [7, 'file', 144464]
# [7, 'file', 118500]
# [7, 'dir', 'pjts']
# [8, 'file', 173783]
# [8, 'file', 103088]
# [8, 'file', 39332]
# [8, 'file', 266947]
# [6, 'dir', 'qzs']
# [7, 'file', 11155]
# [6, 'dir', 'ssdlqcrw']
# [7, 'file', 192414]
# [5, 'dir', 'nztw']
# [6, 'file', 313009]
# [4, 'dir', 'nztw']
# [5, 'file', 280535]
# [5, 'file', 269725]
# [4, 'dir', 'pvsjpn']
# [5, 'file', 105150]
# [5, 'file', 142501]
# [3, 'dir', 'pjts']
# [4, 'file', 259357]
# [4, 'dir', 'btc']
# [5, 'file', 5264]
# [4, 'dir', 'tpwcmvch']
# [5, 'file', 141657]
# [5, 'file', 15650]
# [5, 'file', 182100]
# [5, 'file', 302332]
# [5, 'file', 244799]
# [5, 'dir', 'nlrq']
# [6, 'file', 207207]
# [6, 'dir', 'dtbzzl']
# [7, 'file', 271143]
# [5, 'dir', 'wvnqzjf']
# [6, 'file', 64128]
# [2, 'dir', 'vhvn']
# [3, 'file', 187526]
# [2, 'dir', 'vrt']
# [3, 'file', 270995]
# [3, 'file', 137476]
# [3, 'dir', 'drrnm']
# [4, 'file', 250912]
# [3, 'dir', 'fqr']
# [4, 'file', 229272]
# [4, 'file', 170643]
# [4, 'dir', 'nztw']
# [5, 'dir', 'bqf']
# [6, 'file', 9998]
# [2, 'dir', 'zgrjmtcq']
# [3, 'file', 109025]
# [1, 'dir', 'ftrccld']
# [2, 'file', 22306]
# [2, 'file', 190320]
# [2, 'file', 295676]
# [2, 'file', 135025]
# [2, 'file', 247764]
# [2, 'dir', 'dtbzzl']
# [3, 'dir', 'fgwh']
# [4, 'dir', 'dpdvswq']
# [5, 'file', 248465]
# [5, 'dir', 'jsstq']
# [6, 'file', 252517]
# [2, 'dir', 'fvmh']
# [3, 'file', 303052]
# [3, 'file', 77238]
# [3, 'file', 238683]
# [3, 'dir', 'djcn']
# [4, 'file', 8600]
# [3, 'dir', 'dtbzzl']
# [4, 'dir', 'sppdjcm']
# [5, 'file', 237925]
# [5, 'file', 314661]
# [5, 'dir', 'fghb']
# [6, 'file', 280081]
# [6, 'file', 88448]
# [5, 'dir', 'pfjdsm']
# [6, 'file', 256877]
# [6, 'file', 127978]
# [6, 'file', 103674]
# [5, 'dir', 'pjts']
# [6, 'file', 191709]
# [4, 'dir', 'vtnzqtvj']
# [5, 'dir', 'rrl']
# [6, 'file', 281036]
# [6, 'file', 245082]
# [6, 'dir', 'lzlswv']
# [7, 'dir', 'dmh']
# [8, 'file', 41234]
# [8, 'file', 233542]
# [6, 'dir', 'sjsqnvq']
# [7, 'file', 221327]
# [3, 'dir', 'mvppnhr']
# [4, 'file', 176153]
# [4, 'dir', 'ldwv']
# [5, 'file', 161179]
# [4, 'dir', 'rmdjdqvl']
# [5, 'dir', 'gnztqmhv']
# [6, 'file', 176043]
# [5, 'dir', 'lpmhfr']
# [6, 'dir', 'jrrdsd']
# [7, 'file', 114477]
# [5, 'dir', 'tphjm']
# [6, 'file', 74809]
# [4, 'dir', 'tmj']
# [5, 'file', 252001]
# [5, 'file', 49666]
# [5, 'file', 139885]
# [5, 'file', 116339]
# [4, 'dir', 'vhvn']
# [5, 'file', 89397]
# [5, 'file', 105454]
# [5, 'file', 280352]
# [3, 'dir', 'zdqlwnc']
# [4, 'file', 8676]
# [4, 'file', 99885]
# [4, 'file', 234563]
# [4, 'dir', 'fbhcv']
# [5, 'file', 71695]
# [5, 'file', 296401]
# [4, 'dir', 'rsdltnvc']
# [5, 'file', 41623]
# [5, 'file', 233747]
# [2, 'dir', 'fwztt']
# [3, 'file', 96594]
# [3, 'file', 245415]
# [3, 'file', 129782]
# [3, 'file', 308104]
# [3, 'file', 155109]
# [3, 'dir', 'ssdlqcrw']
# [4, 'file', 292228]
# [4, 'file', 107505]
# [4, 'file', 181384]
# [4, 'dir', 'bzd']
# [5, 'file', 84648]
# [5, 'file', 171457]
# [3, 'dir', 'vvzsr']
# [4, 'file', 147437]
# [4, 'file', 197054]
# [4, 'dir', 'bcdqrs']
# [5, 'file', 297401]
# [5, 'file', 136072]
# [4, 'dir', 'ssdlqcrw']
# [5, 'file', 293104]
# [4, 'dir', 'vhvn']
# [5, 'file', 178932]
# [4, 'dir', 'wthshgg']
# [5, 'file', 88822]
# [5, 'file', 255776]
# [5, 'file', 163501]
# [5, 'dir', 'dppwvtmp']
# [6, 'file', 45608]
# [6, 'file', 164648]
# [6, 'file', 65225]
# [5, 'dir', 'ljgszd']
# [6, 'file', 125627]
# [5, 'dir', 'vbjsmgp']
# [6, 'file', 236951]
# [5, 'dir', 'vzqc']
# [6, 'file', 234565]
# [6, 'file', 254986]
# [6, 'file', 164495]
# [6, 'dir', 'vhvn']
# [7, 'file', 199196]
# [5, 'dir', 'zmpdrpd']
# [6, 'file', 123210]
# [6, 'file', 141163]
# [6, 'file', 302352]
# [6, 'file', 92016]
# [2, 'dir', 'lsvvn']
# [3, 'file', 282867]
# [2, 'dir', 'pjts']
# [3, 'file', 40866]
# [2, 'dir', 'qglhlggq']
# [3, 'file', 19577]
# [3, 'file', 21171]
# [3, 'file', 136074]
# [3, 'file', 212428]
# [3, 'file', 274669]
# [3, 'dir', 'vhvn']
# [4, 'file', 183301]
# [4, 'file', 84069]
# [4, 'file', 126627]
# [4, 'file', 47594]
# [4, 'file', 154978]
# [4, 'dir', 'dtbzzl']
# [5, 'file', 50385]
# [5, 'file', 22427]
# [4, 'dir', 'mdng']
# [5, 'file', 224013]
# [5, 'file', 121884]
# [5, 'file', 142950]
# [5, 'file', 9710]
# [5, 'dir', 'gdqqtvnp']
# [6, 'file', 292349]
# [5, 'dir', 'nrmhpblm']
# [6, 'file', 52703]
# [6, 'file', 78268]
# [5, 'dir', 'vhvn']
# [6, 'file', 274549]
# [4, 'dir', 'ptqq']
# [5, 'file', 257967]
# [5, 'file', 166450]
# [3, 'dir', 'wpvq']
# [4, 'file', 173437]
# [2, 'dir', 'rslphgp']
# [3, 'file', 29192]
# [3, 'file', 18984]
# [3, 'file', 302301]
# [3, 'file', 291211]
# [2, 'dir', 'vhvn']
# [3, 'dir', 'ssdlqcrw']
# [4, 'file', 76864]
# [4, 'file', 26365]
# [4, 'file', 185966]
# [1, 'dir', 'jjlbmtw']
# [2, 'file', 211239]
# [2, 'file', 230020]
# [2, 'file', 109641]
# [1, 'dir', 'jpncfpb']
# [2, 'file', 286054]
# [2, 'file', 260831]
# [2, 'dir', 'hjgwcmh']
# [3, 'file', 92277]
# [3, 'dir', 'fmst']
# [4, 'file', 105833]
# [4, 'file', 315858]
# [4, 'file', 233459]
# [3, 'dir', 'gzjq']
# [4, 'dir', 'prjqfwf']
# [5, 'file', 151003]
# [4, 'dir', 'ssdlqcrw']
# [5, 'file', 103688]
# [2, 'dir', 'vhvn']
# [3, 'file', 14901]
# [3, 'file', 98212]
# [1, 'dir', 'mddr']
# [2, 'dir', 'qpfjp']
# [3, 'dir', 'cfhv']
# [4, 'dir', 'ssdlqcrw']
# [5, 'file', 134280]
# [1, 'dir', 'mthvntdd']
# [2, 'file', 62389]
# [2, 'file', 6743]
# [2, 'dir', 'bcdcz']
# [3, 'file', 213688]
# [3, 'file', 100222]
# [3, 'file', 115627]
# [3, 'file', 258672]
# [3, 'file', 163927]
# [3, 'dir', 'lbvbc']
# [4, 'file', 224836]
# [4, 'file', 103806]
# [3, 'dir', 'tvgclpsc']
# [4, 'file', 76900]
# [4, 'file', 282820]
# [2, 'dir', 'cngbf']
# [3, 'file', 12089]
# [3, 'file', 38052]
# [3, 'dir', 'hstph']
# [4, 'file', 172788]
# [3, 'dir', 'qrnpjz']
# [4, 'dir', 'blzc']
# [5, 'file', 108342]
# [4, 'dir', 'rvl']
# [5, 'dir', 'bcrf']
# [6, 'file', 182498]
# [6, 'file', 14228]
# [6, 'dir', 'dcb']
# [7, 'dir', 'zlgjzcjv']
# [8, 'file', 18316]
# [6, 'dir', 'gnhvtgm']
# [7, 'file', 110236]
# [5, 'dir', 'sjbr']
# [6, 'file', 133009]
# [6, 'file', 315907]
# [4, 'dir', 'zvhtzqqc']
# [5, 'file', 274977]
# [5, 'dir', 'fglfpn']
# [6, 'file', 39153]
# [5, 'dir', 'gtzrq']
# [6, 'file', 60625]
# [5, 'dir', 'hfgdcf']
# [6, 'file', 36016]
# [5, 'dir', 'msc']
# [6, 'file', 56601]
# [6, 'dir', 'hrz']
# [7, 'file', 241511]
# [7, 'file', 286505]
# [6, 'dir', 'vlhllqz']
# [7, 'file', 157880]
# [5, 'dir', 'ssdlqcrw']
# [6, 'file', 121507]
# [6, 'file', 295897]
# [6, 'file', 12047]
# [2, 'dir', 'mqjjbq']
# [3, 'file', 157818]
# [3, 'file', 119103]
# [3, 'file', 141463]
# [3, 'file', 197900]
# [3, 'file', 175029]
# [3, 'dir', 'fmvp']
# [4, 'file', 131432]
# [4, 'file', 98127]
# [4, 'file', 9179]
# [4, 'file', 121310]
# [4, 'dir', 'dhnn']
# [5, 'file', 173921]
# [5, 'file', 58654]
# [4, 'dir', 'dlcvwqw']
# [5, 'file', 285116]
# [4, 'dir', 'jzqt']
# [5, 'file', 104478]
# [5, 'file', 299622]
# [5, 'file', 301236]
# [5, 'file', 136737]
# [5, 'file', 12932]
# [5, 'dir', 'nsvlqq']
# [6, 'file', 111712]
# [6, 'file', 213593]
# [5, 'dir', 'vmp']
# [6, 'file', 104275]
# [4, 'dir', 'nvsdbjj']
# [5, 'file', 180999]
# [5, 'file', 219819]
# [4, 'dir', 'pjts']
# [5, 'file', 111715]
# [3, 'dir', 'rhldnjlt']
# [4, 'dir', 'ffhcbvmf']
# [5, 'file', 247668]
# [4, 'dir', 'vprlq']
# [5, 'file', 168090]
# [5, 'file', 68360]
# [5, 'file', 304580]
# [2, 'dir', 'nhblb']
# [3, 'file', 154794]
# [3, 'file', 50110]
# [3, 'dir', 'nfwl']
# [4, 'dir', 'lqs']
# [5, 'dir', 'mbcft']
# [6, 'file', 78188]
# [6, 'file', 194668]
# [5, 'dir', 'ntmvt']
# [6, 'file', 75647]
# [6, 'file', 186651]
# [5, 'dir', 'nztw']
# [6, 'file', 164920]
# [4, 'dir', 'mlvnlz']
# [5, 'file', 289891]
# [3, 'dir', 'ptc']
# [4, 'file', 190002]
# [3, 'dir', 'rng']
# [4, 'file', 39093]
# [3, 'dir', 'vhvn']
# [4, 'file', 275854]
# [3, 'dir', 'vlj']
# [4, 'file', 203390]
# [4, 'dir', 'qqqrm']
# [5, 'dir', 'wcpllh']
# [6, 'dir', 'pwg']
# [7, 'file', 19102]
# [2, 'dir', 'ssdlqcrw']
# [3, 'file', 181610]
# [2, 'dir', 'ttvgr']
# [3, 'dir', 'vpcpd']
# [4, 'file', 28102]
# [4, 'file', 304017]
# [2, 'dir', 'vdmm']
# [3, 'file', 95079]
# [2, 'dir', 'wnhnwjm']
# [3, 'file', 67931]
# [3, 'file', 22062]
# [3, 'file', 219285]
# [2, 'dir', 'zdvbsb']
# [3, 'file', 293736]
# [1, 'dir', 'ptzsl']
# [2, 'file', 26404]
# [1, 'dir', 'wmqc']
# [2, 'dir', 'dtbzzl']
# [3, 'dir', 'hpzgnb']
# [4, 'file', 189696]
# [2, 'dir', 'hdzmzc']
# [3, 'file', 143510]
# [2, 'dir', 'nmmpwqvz']
# [3, 'file', 276725]
# [2, 'dir', 'qjnm']
# [3, 'file', 202264]

# %%
# Compute sum of sizes of directories with a size under size_limit
size_limit = 100000
size_of_dirs_under_limit = 0
for dir_size in dir_sizes:
    if dir_size <= size_limit:
        size_of_dirs_under_limit += dir_size
print('Sum of sizes of directories under ' + str(size_limit) + ': ' + str(size_of_dirs_under_limit))
# Out:
# Sum of sizes of directories under 100000: 919137

# %% [markdown]
# ## Part 2

# %%
# Compute how much space that needs to be freed for the update
total_disk_space = 70000000
space_required = 30000000
# The largest file size corresponds to the outermost folder, i.e., the total file size
space_used = max(dir_sizes)
free_space = total_disk_space - space_used
needed_space = space_required - free_space
print('Space needed for update: ' + str(needed_space))
# Out:
# Space needed for update: 2805968

# %%
# Find the smallest directory to delete to free up enough space
min_diff = 1e10
size_of_dir_to_delete = 0
for dir_size in dir_sizes:
    if dir_size > needed_space:
        diff = dir_size - needed_space
        if diff < min_diff:
            min_diff = diff
            size_of_dir_to_delete = dir_size
print('The smallest directory that can be deleted to free enough space has size: ' 
      + str(size_of_dir_to_delete))
# Out:
# The smallest directory that can be deleted to free enough space has size: 2877389
